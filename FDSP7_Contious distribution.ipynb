# %%
#for inline plots in jupyter
# %matplotlib inline
#import matplotlib
import matplotlib.pyplot as plt
#for latex equations
from IPython .display import Math,Latex
#for displaying images
from IPython.core.display import  Image
import numpy as np

# %%
#import seaborn
import seaborn as sns
#setting for seaborn plotting stle
sns.set(color_codes=True)
#setting for seaborn plot sizes
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# # uniform Distibution

# %%
#import uniform distribution
from scipy.stats import uniform

# %%
#random num from uniform distribution
n=10000
start=10
width=20
data_uniform = uniform.rvs(size=n,loc=start,scale=width)

# %%
ax=sns.distplot(data_uniform,
               bins=100,
               kde=True,
               color='skyblue',
               hist_kws={"linewidth":15 , 'alpha':1})
ax.set(xlabel="Uniform Distribution",ylabel="Frequency")
# Out:
# C:\Users\suchi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Uniform Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # normal Distribution

# %%
from scipy.stats import norm
# genetate random num from N(0,1)
data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
ax = sns.distplot(data_normal,
                bins=100,
                kde=True,
                color = 'skyblue',
                hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel="frequency")
# Out:
# C:\Users\suchi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'frequency')]

# %% [markdown]
# # explonential Distribution

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1, loc=0, size=1000)

# %%
ax=sns.distplot(data_expon,
               kde=True,
               color='skyblue',
               hist_kws={'linewidth':15,'alpha':1})
ax.set(xlabel='Explonential Distribution',ylabel="Frequency")
# Out:
# C:\Users\suchi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Explonential Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Chi Square Distribution

# %%
from numpy import random
x= random.chisquare(df=2,size=(2,3))
print(x)
# Out:
# [[2.39807671 0.44270181 0.68140382]
#  [3.32003206 3.9545244  0.27022791]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as ans
sns.distplot(random.chisquare(df=1,size=1000 ),hist=False)
plt.show()
# Out:
# C:\Users\suchi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Weibull Distribution

# %%
a=5 #shape

s=np.random.weibull(a,1000)

# %%
#display th eistogram of the sample,along with prob.
import matplotlib.pyplot as plt
x= np.arange(1,100)/50
def weib(x,n,a):
    return (a/n)*(x-1)*np.exp(-(x/n)**a)

# %%
count,bins ,ignored=plt.hist(np.random.weibull(5.,1000))
x=np.arange(1,100.)/50.

scale=count.max()/weib(x,1.,5.).max()
plt.plot(x,weib(x,1.,5.)*scale)
plt.show()
